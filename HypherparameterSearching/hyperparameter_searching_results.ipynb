# %% [markdown]
# LSTM

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import json
from window_generator import *
from model_predict import *
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import KFold
import optuna
import warnings

if __name__ == "__main__":
    warnings.warn(
        "Recent Keras release (2.4.0) simply redirects all APIs "
        "in the standalone keras package to point to tf.keras. "
        "There is now only one Keras: tf.keras. "
        "There may be some breaking changes for some workflows by upgrading to keras 2.4.0. "
        "Test before upgrading. "
        "REF:https://github.com/keras-team/keras/releases/tag/2.4.0"
    )
    #study = optuna.create_study(storage='sqlite:///arx.sqlite3', study_name='arx', direction="maximize")
    study = optuna.study.load_study(study_name='lstm',storage='sqlite:///db_lstm.sqlite3')
    #study.optimize(objective, n_trials=50, timeout=None)

    #fig = optuna.visualization.plot_intermediate_values(study)
    #fig.show()

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

#optuna.visualization.plot_optimization_history(study)
#optuna.visualization.plot_param_importances(study)
#optuna.visualization.plot_parallel_coordinate(study).show(renderer="browser")
# Out:
# /tmp/ipykernel_44234/1809361740.py:14: UserWarning:
#
# Recent Keras release (2.4.0) simply redirects all APIs in the standalone keras package to point to tf.keras. There is now only one Keras: tf.keras. There may be some breaking changes for some workflows by upgrading to keras 2.4.0. Test before upgrading. REF:https://github.com/keras-team/keras/releases/tag/2.4.0
# Number of finished trials: 50
# Best trial:
#   Value: 0.9659780848759025
#   Params:
#     learning_rate: 0.001056364655957735
#     n_units5: 83
#     weight_decay_dense: 2.8059524346886466e-06
#     weight_decay_lstm: 8.494039657372766e-07

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.savefig("history_lstm",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/2781722753.py:2: ExperimentalWarning:
#
# plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.

# %%
plt.figure(figsize=(15,6))
fig = optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig("importance_lstm",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/3753063212.py:2: ExperimentalWarning:
#
# plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.

# %% [markdown]
# HLSTM

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import json
from window_generator import *
from model_predict import *
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import KFold
import optuna
import warnings

if __name__ == "__main__":
    warnings.warn(
        "Recent Keras release (2.4.0) simply redirects all APIs "
        "in the standalone keras package to point to tf.keras. "
        "There is now only one Keras: tf.keras. "
        "There may be some breaking changes for some workflows by upgrading to keras 2.4.0. "
        "Test before upgrading. "
        "REF:https://github.com/keras-team/keras/releases/tag/2.4.0"
    )
    #study = optuna.create_study(storage='sqlite:///arx.sqlite3', study_name='arx', direction="maximize")
    study = optuna.study.load_study(study_name='hlstm',storage='sqlite:///db_hlstm.sqlite3')
    #study.optimize(objective, n_trials=50, timeout=None)

    #fig = optuna.visualization.plot_intermediate_values(study)
    #fig.show()

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

#optuna.visualization.plot_optimization_history(study)
#optuna.visualization.plot_param_importances(study)
#optuna.visualization.plot_parallel_coordinate(study)
# Out:
# Number of finished trials: 50
# Best trial:
#   Value: 0.9676706242520486
#   Params:
#     learning_rate: 0.00039716978550010724
#     n_units5: 124
#     weight_decay_dense: 3.747362360127511e-09
#     weight_decay_lstm: 2.2100110695530286e-07
# /tmp/ipykernel_44234/517982221.py:14: UserWarning:
#
# Recent Keras release (2.4.0) simply redirects all APIs in the standalone keras package to point to tf.keras. There is now only one Keras: tf.keras. There may be some breaking changes for some workflows by upgrading to keras 2.4.0. Test before upgrading. REF:https://github.com/keras-team/keras/releases/tag/2.4.0

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.savefig("history_hlstm",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/3781456891.py:2: ExperimentalWarning:
#
# plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.

# %%
plt.figure(figsize=(10,6))
optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig("importance_hlstm",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/2197703237.py:2: ExperimentalWarning:
#
# plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.

# %% [markdown]
# NARx LSTM

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import json
#from window_generator import *
#from model_predict import *
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import KFold
import optuna
import warnings

if __name__ == "__main__":
    warnings.warn(
        "Recent Keras release (2.4.0) simply redirects all APIs "
        "in the standalone keras package to point to tf.keras. "
        "There is now only one Keras: tf.keras. "
        "There may be some breaking changes for some workflows by upgrading to keras 2.4.0. "
        "Test before upgrading. "
        "REF:https://github.com/keras-team/keras/releases/tag/2.4.0"
    )
    #study = optuna.create_study(storage='sqlite:///arx.sqlite3', study_name='arx', direction="maximize")
    study = optuna.study.load_study(study_name='arx',storage='sqlite:///db_arx.sqlite3')
    #study.optimize(objective, n_trials=50, timeout=None)

    #fig = optuna.visualization.plot_intermediate_values(study)
    #fig.show()

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

#optuna.visualization.plot_optimization_history(study)
#optuna.visualization.plot_param_importances(study)
#optuna.visualization.plot_parallel_coordinate(study)
# Out:
# Number of finished trials: 50
# Best trial:
#   Value: 0.9715402172689966
#   Params:
#     learning_rate: 0.0006610335273169034
#     n_units5: 122
#     weight_decay_dense: 1.6764880716096568e-06
#     weight_decay_lstm: 3.568692538610815e-10
# /tmp/ipykernel_48753/2836827015.py:14: UserWarning: Recent Keras release (2.4.0) simply redirects all APIs in the standalone keras package to point to tf.keras. There is now only one Keras: tf.keras. There may be some breaking changes for some workflows by upgrading to keras 2.4.0. Test before upgrading. REF:https://github.com/keras-team/keras/releases/tag/2.4.0
#   warnings.warn(

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.savefig("history_arx",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/320388758.py:2: ExperimentalWarning:
#
# plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig("important_arx",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_44234/77848797.py:2: ExperimentalWarning:
#
# plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.

# %% [markdown]
# Transformer

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import json
#from window_generator import *
#from model_predict import *
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import KFold
import optuna
import warnings

if __name__ == "__main__":
    warnings.warn(
        "Recent Keras release (2.4.0) simply redirects all APIs "
        "in the standalone keras package to point to tf.keras. "
        "There is now only one Keras: tf.keras. "
        "There may be some breaking changes for some workflows by upgrading to keras 2.4.0. "
        "Test before upgrading. "
        "REF:https://github.com/keras-team/keras/releases/tag/2.4.0"
    )
    #study = optuna.create_study(storage='sqlite:///db_trans.sqlite3', study_name='trans', direction="maximize")
    study = optuna.study.load_study(study_name='trans',storage='sqlite:///db_trans.sqlite3')

    #fig = optuna.visualization.plot_intermediate_values(study)
    #fig.show()

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

#optuna.visualization.plot_optimization_history(study)
#optuna.visualization.plot_param_importances(study)
#optuna.visualization.plot_parallel_coordinate(study)
# Out:
# Number of finished trials: 47
# Best trial:
#   Value: 0.9971856055218831
#   Params:
#     dropout_ratio: 0.10151856402424875
#     layer_num: 6
#     learning_rate: 0.00016998842913476997
# /tmp/ipykernel_48753/72787394.py:15: UserWarning: Recent Keras release (2.4.0) simply redirects all APIs in the standalone keras package to point to tf.keras. There is now only one Keras: tf.keras. There may be some breaking changes for some workflows by upgrading to keras 2.4.0. Test before upgrading. REF:https://github.com/keras-team/keras/releases/tag/2.4.0
#   warnings.warn(

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.savefig("history_trans",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_48753/3721102103.py:2: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study)

# %%
plt.figure(figsize=(8,6))
optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig("important_trans",bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_48753/3200269384.py:2: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
